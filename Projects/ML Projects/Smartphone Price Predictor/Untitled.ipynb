# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import plotly.colors as colors
pio.templates.default = 'plotly_white'

# %%
smartPhone = pd.read_csv('Smartphones.csv')
smartPhone24 = pd.read_csv('Smartphone_2024.csv')

# %%
smartPhone.head()
# Out:
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage   Color Free  Final Price
# 0   8.0    256.0  Yellow  Yes       231.60
# 1   4.0    128.0    Blue  Yes       279.00
# 2   4.0    128.0    Blue  Yes       179.01
# 3   6.0    128.0    Gray  Yes       279.99
# 4  12.0    512.0   White  Yes       799.00

# %%
smartPhone24.head()
# Out:
#    Unnamed: 0              Model    Price  Rating  \
# 0           0         iQOO Z9 5G  ₹19,999     NaN
# 1           1   Nothing Phone 2a  ₹23,999     NaN
# 2           2    Vivo V30 Pro 5G  ₹41,999     NaN
# 3           3        Vivo V30 5G  ₹33,999     NaN
# 4           4  Realme 12 Plus 5G  ₹19,999     NaN
#
#                              Specification  \
# 0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                           Processor                       RAM  \
# 0      Dimensity 7200, Octa Core, 2.8 GHz Processor  8 GB RAM, 128 GB inbuilt
# 1  Dimensity 7200 Pro, Octa Core, 2.8 GHz Processor  8 GB RAM, 128 GB inbuilt
# 2      Dimensity 8200, Octa Core, 3.1 GHz Processor  8 GB RAM, 256 GB inbuilt
# 3  Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor  8 GB RAM, 128 GB inbuilt
# ...

# %%
smartPhone.shape
# Out:
# (1816, 8)

# %%
smartPhone24.shape
# Out:
# (1020, 12)

# %% [markdown]
# ### Clean data Smartphone

# %%
smartPhone.columns
# Out:
# Index(['Smartphone', 'Brand', 'Model', 'RAM', 'Storage', 'Color', 'Free',
#        'Final Price'],
#       dtype='object')

# %%
smartPhone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1816 entries, 0 to 1815
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Smartphone   1816 non-null   object
#  1   Brand        1816 non-null   object
#  2   Model        1816 non-null   object
#  3   RAM          1333 non-null   float64
#  4   Storage      1791 non-null   float64
#  5   Color        1816 non-null   object
#  6   Free         1816 non-null   object
#  7   Final Price  1816 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 113.6+ KB

# %%
smartPhone.describe()
# Out:
#               RAM      Storage  Final Price
# count  1333.00000  1791.000000  1816.000000
# mean      5.96099   162.652150   492.175573
# std       2.66807   139.411605   398.606183
# min       1.00000     2.000000    60.460000
# 25%       4.00000    64.000000   200.990000
# 50%       6.00000   128.000000   349.990000
# 75%       8.00000   256.000000   652.717500
# max      12.00000  1000.000000  2271.280000

# %%
smartPhone.isnull()
# Out:
#       Smartphone  Brand  Model    RAM  Storage  Color   Free  Final Price
# 0          False  False  False  False    False  False  False        False
# 1          False  False  False  False    False  False  False        False
# 2          False  False  False  False    False  False  False        False
# 3          False  False  False  False    False  False  False        False
# 4          False  False  False  False    False  False  False        False
# ...          ...    ...    ...    ...      ...    ...    ...          ...
# 1811       False  False  False  False    False  False  False        False
# 1812       False  False  False  False    False  False  False        False
# 1813       False  False  False  False    False  False  False        False
# 1814       False  False  False  False    False  False  False        False
# 1815       False  False  False  False    False  False  False        False
#
# [1816 rows x 8 columns]

# %%
# remove missing data from rows and col
smartPhone = smartPhone.dropna()

# %%
smartPhone.shape
# Out:
# (1333, 8)

# %%
# remove duplication values
smartPhone.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1811    False
# 1812    False
# 1813    False
# 1814    False
# 1815    False
# Length: 1333, dtype: bool

# %%
smartPhone.drop_duplicates()
# Out:
#                                             Smartphone     Brand  \
# 0                   Realme C55 8/256GB Sunshower Libre    Realme
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4              Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...                                                ...       ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre    Xiaomi
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre    Xiaomi
#
#                Model   RAM  Storage   Color Free  Final Price
# 0                C55   8.0    256.0  Yellow  Yes       231.60
# ...

# %%
smartPhone.sample(4)
# Out:
#                                              Smartphone   Brand       Model  \
# 536             Xiaomi Redmi A2 2/32GB Azul Claro Libre  Xiaomi    Redmi A2
# 517                    Xiaomi 11T 5G 8/128GB Azul Libre  Xiaomi         11T
# 571   OPPO A57s 4/128GB Azul Libre + Cable USB 3.1 T...    OPPO        A57s
# 1802       Xiaomi Mi Note 10 Lite 6/128GB Nebula Purple  Xiaomi  Mi Note 10
#
#       RAM  Storage   Color Free  Final Price
# 536   2.0     32.0    Blue  Yes        79.99
# 517   8.0    128.0    Blue  Yes       399.00
# 571   4.0    128.0    Blue  Yes       202.59
# 1802  6.0    128.0  Purple   No       379.00

# %%
smartPhone['RAM'].max()
# Out:
# 12.0

# %%
# covert datatypes of columns
smartPhone['RAM'] = smartPhone['RAM'].astype(int)
smartPhone['Storage'] = smartPhone['Storage'].astype(int)
# Out:
# /var/folders/5f/0hb_qs091gb66mrrdykchhyw0000gn/T/ipykernel_41758/2289997826.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartPhone['RAM'] = smartPhone['RAM'].astype(int)
# /var/folders/5f/0hb_qs091gb66mrrdykchhyw0000gn/T/ipykernel_41758/2289997826.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartPhone['Storage'] = smartPhone['Storage'].astype(int)

# %%
smartPhone.sample(4)
# Out:
#                                              Smartphone    Brand  \
# 79    Xiaomi Redmi Note 11 Pro Plus 5G 8/256GB Gris ...   Xiaomi
# 1794  Samsung Galaxy Z Fold4 12/512GB Verde Libre + ...  Samsung
# 837   Samsung Galaxy S20 Plus 12/128GB 5G Cloud Blue...  Samsung
# 891                   SPC Smart 3 3/32GB Turquesa Libre      SPC
#
#                Model  RAM  Storage      Color Free  Final Price
# 79            11 Pro    8      256       Gray  Yes       449.99
# 1794  Galaxy Z Fold4   12      512      Green  Yes      1922.93
# 837       Galaxy S20   12      128       Blue  Yes       796.95
# 891          Smart 3    3       32  Turquoise  Yes        99.95

# %%
# convert final price into indian currancy
convert_rate = 85.50
smartPhone['Price'] = smartPhone['Final Price'] * convert_rate

smartPhone.sample(4)
# Out:
# /var/folders/5f/0hb_qs091gb66mrrdykchhyw0000gn/T/ipykernel_41758/1461816691.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartPhone['Price'] = smartPhone['Final Price'] * convert_rate
#                                         Smartphone    Brand           Model  \
# 861   Samsung Galaxy S21 FE 5G 8/256GB Verde Libre  Samsung      Galaxy S21
# 1336              Cubot Note 30 4/64GB Negro Libre    Cubot         Note 30
# 1180     Samsung Galaxy Z Flip4 8/128GB Rosa Libre  Samsung  Galaxy Z Flip4
# 349                      TCL 408 4/64GB Azul Libre      TCL             408
#
#       RAM  Storage  Color Free  Final Price      Price
# 861     8      256  Green  Yes       649.00  55489.500
# ...

# %%
smartPhone['Price'] = smartPhone['Price'].astype(int)

smartPhone.sample(4)
# Out:
# /var/folders/5f/0hb_qs091gb66mrrdykchhyw0000gn/T/ipykernel_41758/2416348787.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smartPhone['Price'] = smartPhone['Price'].astype(int)
#                                              Smartphone   Brand    Model  RAM  \
# 1334                     Cubot Max 3 4/64GB Negro Libre   Cubot    Max 3    4
# 594            OPPO Find X5 Pro 5G 12/256GB Negro Libre    OPPO   X5 Pro   12
# 1397  Huawei P Smart Plus 2019 3/64GB Dual Sim Negro...  Huawei  P Smart    3
# 965                     realme 7 Pro 8/128GB Azul Libre  Realme        7    8
#
#       Storage  Color Free  Final Price   Price
# 1334       64  Black  Yes       202.26   17293
# 594       256  Black  Yes      1299.00  111064
# ...

# %%
# drop unwanted columns
smartPhone = smartPhone.drop(columns=['Smartphone'])

# %%
smartPhone
# Out:
#          Brand           Model  RAM  Storage   Color  Price
# 0       Realme             C55    8      256  Yellow  19801
# 1      Samsung      Galaxy M23    4      128    Blue  23854
# 2     Motorola        Moto G13    4      128    Blue  15305
# 3       Xiaomi  Redmi Note 11S    6      128    Gray  23939
# 4      Nothing       Phone (2)   12      512   White  68314
# ...        ...             ...  ...      ...     ...    ...
# 1811    Xiaomi    Redmi Note 8    4       64    Blue  21290
# 1812    Xiaomi   Redmi Note 8T    4      128    Blue  17100
# 1813    Xiaomi    Redmi Note 9    4      128   White  22999
# 1814    Xiaomi         Note 9S    4       64    Gray  18040
# 1815    Xiaomi         Note 9S    6      128    Gray  24709
#
# [1333 rows x 6 columns]

# %%
# Extract the brand using regex
smartPhone24['Brand'] = smartPhone24['Model'].str.extract(r'^(\w+)', expand=True)

smartPhone24.sample(4)
# Out:
#      Unnamed: 0                                    Model    Price  Rating  \
# 404         404     Realme GT Neo 3 Thor Limited Edition  ₹25,999     NaN
# 170         170  Samsung Galaxy F14 5G (6GB RAM + 128GB)  ₹10,490    71.0
# 237         237                           Tecno Spark 20  ₹10,499    78.0
# 739         739                 Xiaomi Redmi Note 11T 5G  ₹16,999    79.0
#
#                                       Specification  \
# 404         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 170              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 237                  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 739  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
#
#                                            Processor  \
# 404   Dimensity  8100, Octa Core, 2.85 GHz Processor
# 170                 Exynos 1330, Octa Core Processor
# 237            Helio G85, Octa Core, 2 GHz Processor
# 739  Dimensity  810 5G, Octa Core, 2.4 GHz Processor
#
# ...

# %%
smartPhone24.drop_duplicates()
# Out:
#       Unnamed: 0              Model    Price  Rating  \
# 0              0         iQOO Z9 5G  ₹19,999     NaN
# 1              1   Nothing Phone 2a  ₹23,999     NaN
# 2              2    Vivo V30 Pro 5G  ₹41,999     NaN
# 3              3        Vivo V30 5G  ₹33,999     NaN
# 4              4  Realme 12 Plus 5G  ₹19,999     NaN
# ...          ...                ...      ...     ...
# 1015        1015       GFive Z9 New     ₹664     NaN
# 1016        1016   itel Ace 2 Heera     ₹854     NaN
# 1017        1017     Karbonn ‎KX11I     ₹899     NaN
# 1018        1018         MTR Fold Z   ₹1,600     NaN
# 1019        1019          Tryto Neo     ₹680     NaN
#
#                                 Specification  \
# 0          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 2          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
smartPhone24.dropna()
# Out:
#      Unnamed: 0                                     Model    Price  Rating  \
# 6             6                     Samsung Galaxy F15 5G  ₹12,999    75.0
# 9             9    Motorola Moto G34 5G (8GB RAM + 128GB)  ₹11,999    77.0
# 21           21  Samsung Galaxy F15 5G (6GB RAM +  128GB)  ₹14,499    77.0
# 25           25                              Realme 12 5G  ₹16,990    78.0
# 27           27                   Xiaomi Redmi Note 12 5G  ₹11,159    77.0
# ..          ...                                       ...      ...     ...
# 981         981        Xiaomi Redmi Note 4 (3GB RAM+32GB)   ₹7,449    61.0
# 984         984                   Lava Pixel V2 (3GB RAM)   ₹4,499    52.0
# 985         985                               Lyf Earth 1   ₹4,538    60.0
# 986         986                 Motorola Moto G (3rd Gen)   ₹6,990    51.0
# 999         999                iKall Z2 (4GB RAM + 32 GB)   ₹5,299    54.0
#
#                                       Specification  \
# ...

# %%
# extract RAM value (numeric)
smartPhone24['RAM'] = smartPhone24['RAM'].str.extract(r'(\d+)\s*GB\s*RAM', expand=True).astype(float)
# storage
smartPhone24['Storage'] = smartPhone24['RAM'].str.extract(r'(\d+)\s*GB\s*inbuilt', expand=True).astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 4
#       2 smartPhone24['RAM'] = smartPhone24['RAM'].str.extract(r'(\d+)\s*GB\s*RAM', expand=True).astype(float)
#       3 # storage
# ----> 4 smartPhone24['Storage'] = smartPhone24['RAM'].str.extract(r'(\d+)\s*GB\s*inbuilt', expand=True).astype(float)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# ...

# %%
smartPhone24.sample(4)
# Out:
#      Unnamed: 0                                         Model    Price  \
# 721         721                           Infinix Hot 12 Play   ₹7,990
# 928         928  Samsung Galaxy S21 Plus 5G (8GB RAM + 256GB)  ₹85,999
# 410         410                   Realme GT Master Edition 5G  ₹23,999
# 425         425               Lava Blaze 5G (6GB RAM + 128GB)   ₹9,799
#
#      Rating                            Specification  \
# 721    66.0           Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 928     NaN  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 410     NaN  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 425    75.0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                            Processor  RAM  \
# 721        Tiger T610, Octa Core, 1.82 GHz Processor  NaN
# 928        Exynos 2100, Octa Core, 2.9 GHz Processor  NaN
# 410  Snapdragon  778G , Octa Core, 2.4 GHz Processor  NaN
# 425   Dimensity 700 5G, Octa Core, 2.2 GHz Processor  NaN
#
# ...
